# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'D:\\Sumit Codes\\Fire\\yolov8n.pt')
results = trained_model('D:\\Sumit Codes\\Fire\\test\\images\\115_JPG.rf.1bfddc11e7d1ff4073daba3303089e5a.jpg')
# Out:
# image 1/1 D:\Sumit Codes\Fire\train\images\1633_jpg.rf.7e875a993fa70cdb0d2df00c2d82b3f6.jpg: 640x640 (no detections), 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
