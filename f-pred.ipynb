# %%
from ultralytics import YOLO

# %%
trained_model = YOLO(r'D:\\Sumit Codes\\Fire\\yolov8n.pt')
results = trained_model('D:\\Sumit Codes\\Fire\\test\\images\\115_JPG.rf.1bfddc11e7d1ff4073daba3303089e5a.jpg')
# Out:
# image 1/1 D:\Sumit Codes\Fire\test\images\115_JPG.rf.1bfddc11e7d1ff4073daba3303089e5a.jpg: 640x640 (no detections), 61.2ms
# Speed: 3.2ms preprocess, 61.2ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from PIL import Image
# Ensure matplotlib inline mode
# %matplotlib inline
# Assuming results[0].plot() returns an array
image_array = results[0].plot()

# Display the image
plt.imshow(image_array)
plt.axis('off')  # Hide axes
plt.show()
